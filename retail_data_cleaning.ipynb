# %% [markdown]
# ##Retail Data Cleaning

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read in csv
df = pd.read_csv("retail_store_sales.csv")

df.isnull().sum() #check for nulls in each category
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df.head(50)
# Out:
#    Transaction ID Customer ID                            Category  \
# 0     TXN_6867343     CUST_09                          Patisserie
# 1     TXN_3731986     CUST_22                       Milk Products
# 2     TXN_9303719     CUST_02                            Butchers
# 3     TXN_9458126     CUST_06                           Beverages
# 4     TXN_4575373     CUST_05                                Food
# 5     TXN_7482416     CUST_09                          Patisserie
# 6     TXN_3652209     CUST_07                                Food
# 7     TXN_1372952     CUST_21                           Furniture
# 8     TXN_9728486     CUST_23                           Furniture
# 9     TXN_2722661     CUST_25                            Butchers
# 10    TXN_8776416     CUST_22                            Butchers
# 11    TXN_5422631     CUST_09                       Milk Products
# 12    TXN_5874772     CUST_23                                Food
# 13    TXN_4413070     CUST_14                          Patisserie
# 14    TXN_2490363     CUST_09                       Milk Products
# 15    TXN_1809665     CUST_14                           Beverages
# 16    TXN_7563311     CUST_23                          Patisserie
# 17    TXN_9634894     CUST_15                       Milk Products
# 18    TXN_4396807     CUST_17       Electric household essentials
# 19    TXN_4206593     CUST_01                           Furniture
# 20    TXN_9939063     CUST_14                           Beverages
# 21    TXN_8685338     CUST_15                       Milk Products
# 22    TXN_6547964     CUST_10       Electric household essentials
# 23    TXN_3314099     CUST_04                                Food
# 24    TXN_9980736     CUST_13                           Furniture
# 25    TXN_3481599     CUST_05                           Furniture
# 26    TXN_9057609     CUST_18                            Butchers
# 27    TXN_1599706     CUST_14                           Furniture
# 28    TXN_1598860     CUST_08                                Food
# 29    TXN_7138501     CUST_18                          Patisserie
# 30    TXN_5444504     CUST_05                                Food
# 31    TXN_4353295     CUST_22                          Patisserie
# 32    TXN_1543244     CUST_20                                Food
# 33    TXN_1494700     CUST_12       Electric household essentials
# 34    TXN_1621497     CUST_06                          Patisserie
# 35    TXN_6398436     CUST_15                           Beverages
# 36    TXN_9065245     CUST_02                                Food
# 37    TXN_6963438     CUST_11                           Furniture
# 38    TXN_8312797     CUST_14                           Beverages
# 39    TXN_5836005     CUST_19                            Butchers
# 40    TXN_4223250     CUST_16                           Beverages
# 41    TXN_1019817     CUST_16       Electric household essentials
# 42    TXN_1110407     CUST_25                            Butchers
# 43    TXN_6276518     CUST_24                           Beverages
# 44    TXN_4740738     CUST_25                                Food
# 45    TXN_9587232     CUST_20                                Food
# 46    TXN_6404316     CUST_04  Computers and electric accessories
# 47    TXN_9331642     CUST_12                          Patisserie
# 48    TXN_9729422     CUST_13                            Butchers
# 49    TXN_8425168     CUST_25                       Milk Products
#
#             Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0    Item_10_PAT            18.5      10.0        185.0  Digital Wallet
# 1   Item_17_MILK            29.0       9.0        261.0  Digital Wallet
# 2    Item_12_BUT            21.5       2.0         43.0     Credit Card
# 3    Item_16_BEV            27.5       9.0        247.5     Credit Card
# 4    Item_6_FOOD            12.5       7.0         87.5  Digital Wallet
# 5            NaN             NaN      10.0        200.0     Credit Card
# 6    Item_1_FOOD             5.0       8.0         40.0     Credit Card
# 7            NaN            33.5       NaN          NaN  Digital Wallet
# 8    Item_16_FUR            27.5       1.0         27.5     Credit Card
# 9    Item_22_BUT            36.5       3.0        109.5            Cash
# 10    Item_3_BUT             8.0       9.0         72.0            Cash
# 11           NaN             NaN       8.0         52.0  Digital Wallet
# 12   Item_2_FOOD             6.5       7.0         45.5            Cash
# 13   Item_24_PAT            39.5       6.0        237.0  Digital Wallet
# 14  Item_16_MILK            27.5       2.0         55.0  Digital Wallet
# 15           NaN            24.5       NaN          NaN     Credit Card
# 16   Item_17_PAT            29.0       8.0        232.0            Cash
# 17           NaN             NaN      10.0        275.0  Digital Wallet
# 18   Item_13_EHE            23.0       1.0         23.0  Digital Wallet
# 19           NaN            35.0       NaN          NaN  Digital Wallet
# 20    Item_7_BEV            14.0       9.0        126.0  Digital Wallet
# 21           NaN             NaN       3.0        105.0     Credit Card
# 22    Item_4_EHE             9.5       7.0         66.5            Cash
# 23  Item_10_FOOD            18.5       1.0         18.5            Cash
# 24   Item_14_FUR            24.5       2.0         49.0            Cash
# 25           NaN            39.5       NaN          NaN            Cash
# 26   Item_20_BUT            33.5       4.0        134.0     Credit Card
# 27   Item_25_FUR            41.0      10.0        410.0     Credit Card
# 28  Item_14_FOOD            24.5      10.0        245.0            Cash
# 29   Item_22_PAT            36.5       5.0        182.5     Credit Card
# 30  Item_11_FOOD            20.0      10.0        200.0  Digital Wallet
# 31    Item_6_PAT            12.5       8.0        100.0     Credit Card
# 32           NaN             NaN       8.0        196.0     Credit Card
# 33   Item_21_EHE            35.0       9.0        315.0     Credit Card
# 34           NaN            23.0       NaN          NaN            Cash
# 35   Item_25_BEV            41.0       7.0        287.0     Credit Card
# 36  Item_23_FOOD            38.0       2.0         76.0  Digital Wallet
# 37   Item_10_FUR            18.5       5.0         92.5     Credit Card
# 38   Item_11_BEV            20.0       5.0        100.0  Digital Wallet
# 39   Item_23_BUT            38.0       5.0        190.0     Credit Card
# 40   Item_22_BEV            36.5       7.0        255.5            Cash
# 41   Item_10_EHE            18.5       5.0         92.5            Cash
# 42   Item_24_BUT            39.5       7.0        276.5  Digital Wallet
# 43    Item_8_BEV            15.5       3.0         46.5            Cash
# 44   Item_3_FOOD             8.0       1.0          8.0  Digital Wallet
# 45  Item_12_FOOD            21.5       5.0        107.5  Digital Wallet
# 46   Item_16_CEA            27.5       6.0        165.0     Credit Card
# 47   Item_11_PAT            20.0       4.0         80.0     Credit Card
# 48   Item_16_BUT            27.5       6.0        165.0     Credit Card
# 49  Item_16_MILK            27.5       7.0        192.5            Cash
#
#     Location Transaction Date Discount Applied
# 0     Online       2024-04-08             True
# 1     Online       2023-07-23             True
# 2     Online       2022-10-05            False
# 3     Online       2022-05-07              NaN
# 4     Online       2022-10-02            False
# 5     Online       2023-11-30              NaN
# 6   In-store       2023-06-10             True
# 7   In-store       2024-04-02             True
# 8   In-store       2023-04-26            False
# 9     Online       2024-03-14            False
# 10  In-store       2024-12-14             True
# 11  In-store       2025-01-12             True
# 12    Online       2023-09-09             True
# 13  In-store       2022-05-20            False
# 14    Online       2022-05-22              NaN
# 15  In-store       2022-05-11              NaN
# 16    Online       2024-11-16             True
# 17    Online       2022-04-17              NaN
# 18  In-store       2022-02-07            False
# 19    Online       2025-01-13            False
# 20  In-store       2024-01-14              NaN
# 21  In-store       2023-10-29              NaN
# 22  In-store       2022-08-15              NaN
# 23    Online       2023-09-30            False
# 24    Online       2023-08-29            False
# 25    Online       2022-09-08            False
# 26  In-store       2022-03-16             True
# 27  In-store       2024-03-24             True
# 28  In-store       2022-10-23             True
# 29  In-store       2022-03-10            False
# 30    Online       2022-04-26            False
# 31    Online       2022-04-05             True
# 32    Online       2024-10-25             True
# 33  In-store       2024-03-07              NaN
# 34  In-store       2023-02-18              NaN
# 35  In-store       2024-06-03             True
# 36  In-store       2024-03-10            False
# 37    Online       2024-04-23             True
# 38    Online       2022-06-03              NaN
# 39  In-store       2024-10-19            False
# 40    Online       2023-05-31             True
# 41    Online       2022-08-01              NaN
# 42  In-store       2022-10-21              NaN
# 43  In-store       2024-04-08              NaN
# 44  In-store       2022-04-19              NaN
# 45    Online       2023-02-28             True
# 46    Online       2022-04-06            False
# 47    Online       2022-07-06             True
# 48    Online       2024-12-31             True
# 49  In-store       2022-03-12              NaN

# %% [markdown]
# Fix item category

# %%
df.Item.isna().sum()
# Out:
# 1213

# %%
#extract rows where the Item column ends with 'FOOD'
food_items = df[df['Item'].str.endswith('FOOD', na=False)] #just for checking
food_items[['Item', 'Price Per Unit']].head(50)
# Out:
#              Item  Price Per Unit
# 4     Item_6_FOOD            12.5
# 6     Item_1_FOOD             5.0
# 12    Item_2_FOOD             6.5
# 23   Item_10_FOOD            18.5
# 28   Item_14_FOOD            24.5
# 30   Item_11_FOOD            20.0
# 36   Item_23_FOOD            38.0
# 44    Item_3_FOOD             8.0
# 45   Item_12_FOOD            21.5
# 52   Item_12_FOOD            21.5
# 64   Item_22_FOOD            36.5
# 69   Item_18_FOOD            30.5
# 78   Item_20_FOOD            33.5
# 85    Item_7_FOOD            14.0
# 89    Item_4_FOOD             9.5
# 98   Item_11_FOOD            20.0
# 99   Item_18_FOOD            30.5
# 100  Item_20_FOOD            33.5
# 102  Item_18_FOOD            30.5
# 110  Item_22_FOOD            36.5
# 111   Item_9_FOOD            17.0
# 119   Item_3_FOOD             8.0
# 129  Item_24_FOOD            39.5
# 146  Item_24_FOOD            39.5
# 150  Item_18_FOOD            30.5
# 160  Item_14_FOOD            24.5
# 163   Item_9_FOOD            17.0
# 176  Item_20_FOOD            33.5
# 189  Item_20_FOOD            33.5
# 201  Item_25_FOOD            41.0
# 206  Item_18_FOOD            30.5
# 213   Item_6_FOOD            12.5
# 226  Item_25_FOOD            41.0
# 235   Item_5_FOOD            11.0
# 238  Item_12_FOOD            21.5
# 243   Item_3_FOOD             8.0
# 254  Item_10_FOOD            18.5
# 258  Item_14_FOOD            24.5
# 298  Item_13_FOOD            23.0
# 305  Item_13_FOOD            23.0
# 311  Item_17_FOOD            29.0
# 313  Item_13_FOOD            23.0
# 331  Item_18_FOOD            30.5
# 338  Item_20_FOOD            33.5
# 339  Item_25_FOOD            41.0
# 352  Item_14_FOOD            24.5
# 363  Item_12_FOOD            21.5
# 366  Item_20_FOOD            33.5
# 367  Item_11_FOOD            20.0
# 403  Item_11_FOOD            20.0

# %%
item_price_summary = df.groupby(['Category', 'Item'])['Price Per Unit'].unique().reset_index() #see unique values for random category
item_price_summary.head(50)
# Out:
#      Category         Item Price Per Unit
# 0   Beverages  Item_10_BEV         [18.5]
# 1   Beverages  Item_11_BEV         [20.0]
# 2   Beverages  Item_12_BEV         [21.5]
# 3   Beverages  Item_13_BEV         [23.0]
# 4   Beverages  Item_14_BEV         [24.5]
# 5   Beverages  Item_15_BEV         [26.0]
# 6   Beverages  Item_16_BEV         [27.5]
# 7   Beverages  Item_17_BEV         [29.0]
# 8   Beverages  Item_18_BEV         [30.5]
# 9   Beverages  Item_19_BEV         [32.0]
# 10  Beverages   Item_1_BEV          [5.0]
# 11  Beverages  Item_20_BEV         [33.5]
# 12  Beverages  Item_21_BEV         [35.0]
# 13  Beverages  Item_22_BEV         [36.5]
# 14  Beverages  Item_23_BEV         [38.0]
# 15  Beverages  Item_24_BEV         [39.5]
# 16  Beverages  Item_25_BEV         [41.0]
# 17  Beverages   Item_2_BEV          [6.5]
# 18  Beverages   Item_3_BEV          [8.0]
# 19  Beverages   Item_4_BEV          [9.5]
# 20  Beverages   Item_5_BEV         [11.0]
# 21  Beverages   Item_6_BEV         [12.5]
# 22  Beverages   Item_7_BEV         [14.0]
# 23  Beverages   Item_8_BEV         [15.5]
# 24  Beverages   Item_9_BEV         [17.0]
# 25   Butchers  Item_10_BUT         [18.5]
# 26   Butchers  Item_11_BUT         [20.0]
# 27   Butchers  Item_12_BUT         [21.5]
# 28   Butchers  Item_13_BUT         [23.0]
# 29   Butchers  Item_14_BUT         [24.5]
# 30   Butchers  Item_15_BUT         [26.0]
# 31   Butchers  Item_16_BUT         [27.5]
# 32   Butchers  Item_17_BUT         [29.0]
# 33   Butchers  Item_18_BUT         [30.5]
# 34   Butchers  Item_19_BUT         [32.0]
# 35   Butchers   Item_1_BUT          [5.0]
# 36   Butchers  Item_20_BUT         [33.5]
# 37   Butchers  Item_21_BUT         [35.0]
# 38   Butchers  Item_22_BUT         [36.5]
# 39   Butchers  Item_23_BUT         [38.0]
# 40   Butchers  Item_24_BUT         [39.5]
# 41   Butchers  Item_25_BUT         [41.0]
# 42   Butchers   Item_2_BUT          [6.5]
# 43   Butchers   Item_3_BUT          [8.0]
# 44   Butchers   Item_4_BUT          [9.5]
# 45   Butchers   Item_5_BUT         [11.0]
# 46   Butchers   Item_6_BUT         [12.5]
# 47   Butchers   Item_7_BUT         [14.0]
# 48   Butchers   Item_8_BUT         [15.5]
# 49   Butchers   Item_9_BUT         [17.0]

# %%
#create price to item map
price_to_item_mapping = df.dropna(subset=['Item', 'Price Per Unit'])[['Price Per Unit', 'Item']].drop_duplicates().set_index('Price Per Unit')['Item'].to_dict()

#fill missing Item values based on the price to item mapping
df['Item'] = df.apply(
    lambda row: price_to_item_mapping.get(row['Price Per Unit'], row['Item']) if pd.isna(row['Item']) else row['Item'],
    axis=1
)

#check if all missing Item values are filled
missing_items = df['Item'].isna().sum()
print(f"Missing items after filling: {missing_items}")
# Out:
# Missing items after filling: 609

# %%
#fill price per unit nan values
df['Price Per Unit'] = df['Price Per Unit'].fillna(df['Total Spent']/df['Quantity'])

# %%
df.head(50)
# Out:
#    Transaction ID Customer ID                            Category  \
# 0     TXN_6867343     CUST_09                          Patisserie
# 1     TXN_3731986     CUST_22                       Milk Products
# 2     TXN_9303719     CUST_02                            Butchers
# 3     TXN_9458126     CUST_06                           Beverages
# 4     TXN_4575373     CUST_05                                Food
# 5     TXN_7482416     CUST_09                          Patisserie
# 6     TXN_3652209     CUST_07                                Food
# 7     TXN_1372952     CUST_21                           Furniture
# 8     TXN_9728486     CUST_23                           Furniture
# 9     TXN_2722661     CUST_25                            Butchers
# 10    TXN_8776416     CUST_22                            Butchers
# 11    TXN_5422631     CUST_09                       Milk Products
# 12    TXN_5874772     CUST_23                                Food
# 13    TXN_4413070     CUST_14                          Patisserie
# 14    TXN_2490363     CUST_09                       Milk Products
# 15    TXN_1809665     CUST_14                           Beverages
# 16    TXN_7563311     CUST_23                          Patisserie
# 17    TXN_9634894     CUST_15                       Milk Products
# 18    TXN_4396807     CUST_17       Electric household essentials
# 19    TXN_4206593     CUST_01                           Furniture
# 20    TXN_9939063     CUST_14                           Beverages
# 21    TXN_8685338     CUST_15                       Milk Products
# 22    TXN_6547964     CUST_10       Electric household essentials
# 23    TXN_3314099     CUST_04                                Food
# 24    TXN_9980736     CUST_13                           Furniture
# 25    TXN_3481599     CUST_05                           Furniture
# 26    TXN_9057609     CUST_18                            Butchers
# 27    TXN_1599706     CUST_14                           Furniture
# 28    TXN_1598860     CUST_08                                Food
# 29    TXN_7138501     CUST_18                          Patisserie
# 30    TXN_5444504     CUST_05                                Food
# 31    TXN_4353295     CUST_22                          Patisserie
# 32    TXN_1543244     CUST_20                                Food
# 33    TXN_1494700     CUST_12       Electric household essentials
# 34    TXN_1621497     CUST_06                          Patisserie
# 35    TXN_6398436     CUST_15                           Beverages
# 36    TXN_9065245     CUST_02                                Food
# 37    TXN_6963438     CUST_11                           Furniture
# 38    TXN_8312797     CUST_14                           Beverages
# 39    TXN_5836005     CUST_19                            Butchers
# 40    TXN_4223250     CUST_16                           Beverages
# 41    TXN_1019817     CUST_16       Electric household essentials
# 42    TXN_1110407     CUST_25                            Butchers
# 43    TXN_6276518     CUST_24                           Beverages
# 44    TXN_4740738     CUST_25                                Food
# 45    TXN_9587232     CUST_20                                Food
# 46    TXN_6404316     CUST_04  Computers and electric accessories
# 47    TXN_9331642     CUST_12                          Patisserie
# 48    TXN_9729422     CUST_13                            Butchers
# 49    TXN_8425168     CUST_25                       Milk Products
#
#             Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0    Item_10_PAT            18.5      10.0        185.0  Digital Wallet
# 1   Item_17_MILK            29.0       9.0        261.0  Digital Wallet
# 2    Item_12_BUT            21.5       2.0         43.0     Credit Card
# 3    Item_16_BEV            27.5       9.0        247.5     Credit Card
# 4    Item_6_FOOD            12.5       7.0         87.5  Digital Wallet
# 5            NaN            20.0      10.0        200.0     Credit Card
# 6    Item_1_FOOD             5.0       8.0         40.0     Credit Card
# 7   Item_20_MILK            33.5       NaN          NaN  Digital Wallet
# 8    Item_16_FUR            27.5       1.0         27.5     Credit Card
# 9    Item_22_BUT            36.5       3.0        109.5            Cash
# 10    Item_3_BUT             8.0       9.0         72.0            Cash
# 11           NaN             6.5       8.0         52.0  Digital Wallet
# 12   Item_2_FOOD             6.5       7.0         45.5            Cash
# 13   Item_24_PAT            39.5       6.0        237.0  Digital Wallet
# 14  Item_16_MILK            27.5       2.0         55.0  Digital Wallet
# 15   Item_14_EHE            24.5       NaN          NaN     Credit Card
# 16   Item_17_PAT            29.0       8.0        232.0            Cash
# 17           NaN            27.5      10.0        275.0  Digital Wallet
# 18   Item_13_EHE            23.0       1.0         23.0  Digital Wallet
# 19  Item_21_FOOD            35.0       NaN          NaN  Digital Wallet
# 20    Item_7_BEV            14.0       9.0        126.0  Digital Wallet
# 21           NaN            35.0       3.0        105.0     Credit Card
# 22    Item_4_EHE             9.5       7.0         66.5            Cash
# 23  Item_10_FOOD            18.5       1.0         18.5            Cash
# 24   Item_14_FUR            24.5       2.0         49.0            Cash
# 25   Item_24_EHE            39.5       NaN          NaN            Cash
# 26   Item_20_BUT            33.5       4.0        134.0     Credit Card
# 27   Item_25_FUR            41.0      10.0        410.0     Credit Card
# 28  Item_14_FOOD            24.5      10.0        245.0            Cash
# 29   Item_22_PAT            36.5       5.0        182.5     Credit Card
# 30  Item_11_FOOD            20.0      10.0        200.0  Digital Wallet
# 31    Item_6_PAT            12.5       8.0        100.0     Credit Card
# 32           NaN            24.5       8.0        196.0     Credit Card
# 33   Item_21_EHE            35.0       9.0        315.0     Credit Card
# 34   Item_13_FUR            23.0       NaN          NaN            Cash
# 35   Item_25_BEV            41.0       7.0        287.0     Credit Card
# 36  Item_23_FOOD            38.0       2.0         76.0  Digital Wallet
# 37   Item_10_FUR            18.5       5.0         92.5     Credit Card
# 38   Item_11_BEV            20.0       5.0        100.0  Digital Wallet
# 39   Item_23_BUT            38.0       5.0        190.0     Credit Card
# 40   Item_22_BEV            36.5       7.0        255.5            Cash
# 41   Item_10_EHE            18.5       5.0         92.5            Cash
# 42   Item_24_BUT            39.5       7.0        276.5  Digital Wallet
# 43    Item_8_BEV            15.5       3.0         46.5            Cash
# 44   Item_3_FOOD             8.0       1.0          8.0  Digital Wallet
# 45  Item_12_FOOD            21.5       5.0        107.5  Digital Wallet
# 46   Item_16_CEA            27.5       6.0        165.0     Credit Card
# 47   Item_11_PAT            20.0       4.0         80.0     Credit Card
# 48   Item_16_BUT            27.5       6.0        165.0     Credit Card
# 49  Item_16_MILK            27.5       7.0        192.5            Cash
#
#     Location Transaction Date Discount Applied
# 0     Online       2024-04-08             True
# 1     Online       2023-07-23             True
# 2     Online       2022-10-05            False
# 3     Online       2022-05-07              NaN
# 4     Online       2022-10-02            False
# 5     Online       2023-11-30              NaN
# 6   In-store       2023-06-10             True
# 7   In-store       2024-04-02             True
# 8   In-store       2023-04-26            False
# 9     Online       2024-03-14            False
# 10  In-store       2024-12-14             True
# 11  In-store       2025-01-12             True
# 12    Online       2023-09-09             True
# 13  In-store       2022-05-20            False
# 14    Online       2022-05-22              NaN
# 15  In-store       2022-05-11              NaN
# 16    Online       2024-11-16             True
# 17    Online       2022-04-17              NaN
# 18  In-store       2022-02-07            False
# 19    Online       2025-01-13            False
# 20  In-store       2024-01-14              NaN
# 21  In-store       2023-10-29              NaN
# 22  In-store       2022-08-15              NaN
# 23    Online       2023-09-30            False
# 24    Online       2023-08-29            False
# 25    Online       2022-09-08            False
# 26  In-store       2022-03-16             True
# 27  In-store       2024-03-24             True
# 28  In-store       2022-10-23             True
# 29  In-store       2022-03-10            False
# 30    Online       2022-04-26            False
# 31    Online       2022-04-05             True
# 32    Online       2024-10-25             True
# 33  In-store       2024-03-07              NaN
# 34  In-store       2023-02-18              NaN
# 35  In-store       2024-06-03             True
# 36  In-store       2024-03-10            False
# 37    Online       2024-04-23             True
# 38    Online       2022-06-03              NaN
# 39  In-store       2024-10-19            False
# 40    Online       2023-05-31             True
# 41    Online       2022-08-01              NaN
# 42  In-store       2022-10-21              NaN
# 43  In-store       2024-04-08              NaN
# 44  In-store       2022-04-19              NaN
# 45    Online       2023-02-28             True
# 46    Online       2022-04-06            False
# 47    Online       2022-07-06             True
# 48    Online       2024-12-31             True
# 49  In-store       2022-03-12              NaN

# %%
#create another price to item map to fix more missing item categories
price_to_item_mapping = df.dropna(subset=['Item', 'Price Per Unit'])[['Price Per Unit', 'Item']].drop_duplicates().set_index('Price Per Unit')['Item'].to_dict()

#fill missing Item values based on the price to item mapping
df['Item'] = df.apply(
    lambda row: price_to_item_mapping.get(row['Price Per Unit'], row['Item']) if pd.isna(row['Item']) else row['Item'],
    axis=1
)

#check if all missing Item values are filled
missing_items = df['Item'].isna().sum()
print(f"Missing items after filling: {missing_items}")
# Out:
# Missing items after filling: 0

# %% [markdown]
# fix quantity and total spent columns

# %%
print(df.Quantity.isna().sum()) #check missing values in both columns
print(df['Total Spent'].isna().sum())
# Out:
# 604
# 604

# %%
# Fill missing Quantity values with the median of the corresponding Item
df['Quantity'] = df.groupby('Item')['Quantity'].transform(lambda x: x.fillna(round(x.median()) if not x.median() is None else x.median()))

# For rows where Quantity is still missing, fallback to the median of the Category
df['Quantity'] = df.groupby('Category')['Quantity'].transform(lambda x: x.fillna(round(x.median()) if not x.median() is None else x.median()))

df['Total Spent'] = df['Total Spent'].fillna(df['Price Per Unit'] * df['Quantity'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              12575 non-null  object
#  4   Price Per Unit    12575 non-null  float64
#  5   Quantity          12575 non-null  float64
#  6   Total Spent       12575 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# discount applied column

# %%
discount_true = df[df['Discount Applied'] == True]
discount_false = df[df['Discount Applied'] == False]

# Compare Price Per Unit and Total Spent
print(discount_true[['Quantity','Price Per Unit', 'Total Spent']].describe())
print(discount_false[['Quantity','Price Per Unit', 'Total Spent']].describe())
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  4219.000000     4219.000000  4219.000000
# mean      5.545864       23.463617   130.748282
# std       2.789513       10.822692    94.307520
# min       1.000000        5.000000     5.000000
# 25%       3.000000       14.000000    52.000000
# 50%       6.000000       23.000000   110.000000
# 75%       8.000000       33.500000   192.000000
# max      10.000000       41.000000   410.000000
#           Quantity  Price Per Unit  Total Spent
# count  4157.000000     4157.000000  4157.000000
# mean      5.592735       23.405942   130.664061
# std       2.784768       10.579682    92.355150
# min       1.000000        5.000000     5.000000
# 25%       3.000000       14.000000    55.500000
# 50%       6.000000       23.000000   110.000000
# 75%       8.000000       32.000000   192.000000
# max      10.000000       41.000000   410.000000

# %%
#fill with unknown since column really has no factors
df['Discount Applied'] = df['Discount Applied'].fillna('Unknown')

# %%
#final cleaned df
df.head(25)
# Out:
#    Transaction ID Customer ID                       Category          Item  \
# 0     TXN_6867343     CUST_09                     Patisserie   Item_10_PAT
# 1     TXN_3731986     CUST_22                  Milk Products  Item_17_MILK
# 2     TXN_9303719     CUST_02                       Butchers   Item_12_BUT
# 3     TXN_9458126     CUST_06                      Beverages   Item_16_BEV
# 4     TXN_4575373     CUST_05                           Food   Item_6_FOOD
# 5     TXN_7482416     CUST_09                     Patisserie   Item_11_EHE
# 6     TXN_3652209     CUST_07                           Food   Item_1_FOOD
# 7     TXN_1372952     CUST_21                      Furniture  Item_20_MILK
# 8     TXN_9728486     CUST_23                      Furniture   Item_16_FUR
# 9     TXN_2722661     CUST_25                       Butchers   Item_22_BUT
# 10    TXN_8776416     CUST_22                       Butchers    Item_3_BUT
# 11    TXN_5422631     CUST_09                  Milk Products    Item_2_PAT
# 12    TXN_5874772     CUST_23                           Food   Item_2_FOOD
# 13    TXN_4413070     CUST_14                     Patisserie   Item_24_PAT
# 14    TXN_2490363     CUST_09                  Milk Products  Item_16_MILK
# 15    TXN_1809665     CUST_14                      Beverages   Item_14_EHE
# 16    TXN_7563311     CUST_23                     Patisserie   Item_17_PAT
# 17    TXN_9634894     CUST_15                  Milk Products   Item_16_EHE
# 18    TXN_4396807     CUST_17  Electric household essentials   Item_13_EHE
# 19    TXN_4206593     CUST_01                      Furniture  Item_21_FOOD
# 20    TXN_9939063     CUST_14                      Beverages    Item_7_BEV
# 21    TXN_8685338     CUST_15                  Milk Products   Item_21_PAT
# 22    TXN_6547964     CUST_10  Electric household essentials    Item_4_EHE
# 23    TXN_3314099     CUST_04                           Food  Item_10_FOOD
# 24    TXN_9980736     CUST_13                      Furniture   Item_14_FUR
#
#     Price Per Unit  Quantity  Total Spent  Payment Method  Location  \
# 0             18.5      10.0        185.0  Digital Wallet    Online
# 1             29.0       9.0        261.0  Digital Wallet    Online
# 2             21.5       2.0         43.0     Credit Card    Online
# 3             27.5       9.0        247.5     Credit Card    Online
# 4             12.5       7.0         87.5  Digital Wallet    Online
# 5             20.0      10.0        200.0     Credit Card    Online
# 6              5.0       8.0         40.0     Credit Card  In-store
# 7             33.5       7.0        234.5  Digital Wallet  In-store
# 8             27.5       1.0         27.5     Credit Card  In-store
# 9             36.5       3.0        109.5            Cash    Online
# 10             8.0       9.0         72.0            Cash  In-store
# 11             6.5       8.0         52.0  Digital Wallet  In-store
# 12             6.5       7.0         45.5            Cash    Online
# 13            39.5       6.0        237.0  Digital Wallet  In-store
# 14            27.5       2.0         55.0  Digital Wallet    Online
# 15            24.5       7.0        171.5     Credit Card  In-store
# 16            29.0       8.0        232.0            Cash    Online
# 17            27.5      10.0        275.0  Digital Wallet    Online
# 18            23.0       1.0         23.0  Digital Wallet  In-store
# 19            35.0       7.0        245.0  Digital Wallet    Online
# 20            14.0       9.0        126.0  Digital Wallet  In-store
# 21            35.0       3.0        105.0     Credit Card  In-store
# 22             9.5       7.0         66.5            Cash  In-store
# 23            18.5       1.0         18.5            Cash    Online
# 24            24.5       2.0         49.0            Cash    Online
#
#    Transaction Date Discount Applied
# 0        2024-04-08             True
# 1        2023-07-23             True
# 2        2022-10-05            False
# 3        2022-05-07          Unknown
# 4        2022-10-02            False
# 5        2023-11-30          Unknown
# 6        2023-06-10             True
# 7        2024-04-02             True
# 8        2023-04-26            False
# 9        2024-03-14            False
# 10       2024-12-14             True
# 11       2025-01-12             True
# 12       2023-09-09             True
# 13       2022-05-20            False
# 14       2022-05-22          Unknown
# 15       2022-05-11          Unknown
# 16       2024-11-16             True
# 17       2022-04-17          Unknown
# 18       2022-02-07            False
# 19       2025-01-13            False
# 20       2024-01-14          Unknown
# 21       2023-10-29          Unknown
# 22       2022-08-15          Unknown
# 23       2023-09-30            False
# 24       2023-08-29            False

# %%
#convert to csv for download

df.to_csv("cleaned_retail_store_sales.csv", index=False)

# Download the file in Google Colab
from google.colab import files
files.download("cleaned_retail_store_sales.csv")
